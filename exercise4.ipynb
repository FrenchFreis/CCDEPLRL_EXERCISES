# %% [markdown]
# <a href="https://colab.research.google.com/github/FrenchFreis/CCDEPLRL_EXERCISES/blob/main/exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 20

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/fruits/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/drive/MyDrive/fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 582 files belonging to 4 classes.
# Found 82 files belonging to 4 classes.
# Found 146 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
class_names = ["apple", "banana", "orange", "pineapple"]
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Rescaling(1./255),
     tf.keras.layers.Conv2D(32, 3, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(64, 3, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(128, 3, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(256, activation="relu"),
     tf.keras.layers.Dropout(0.3),
     tf.keras.layers.Dense(4)
    ]
)

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 40
)
# Out:
# Epoch 1/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 156ms/step - accuracy: 0.4533 - loss: 1.1336 - val_accuracy: 0.8415 - val_loss: 0.5056
# Epoch 2/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.7888 - loss: 0.5373 - val_accuracy: 0.9268 - val_loss: 0.2796
# Epoch 3/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9113 - loss: 0.2750 - val_accuracy: 0.9512 - val_loss: 0.1439
# Epoch 4/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.9031 - loss: 0.2740 - val_accuracy: 0.9390 - val_loss: 0.1638
# Epoch 5/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9568 - loss: 0.1315 - val_accuracy: 0.8659 - val_loss: 0.4000
# Epoch 6/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.9485 - loss: 0.1225 - val_accuracy: 0.9756 - val_loss: 0.0795
# Epoch 7/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9566 - loss: 0.1382 - val_accuracy: 0.9512 - val_loss: 0.1284
# Epoch 8/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9539 - loss: 0.1149 - val_accuracy: 0.9146 - val_loss: 0.2698
# Epoch 9/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9145 - loss: 0.2272 - val_accuracy: 0.9756 - val_loss: 0.1088
# Epoch 10/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.9871 - loss: 0.0614 - val_accuracy: 0.9756 - val_loss: 0.0925
# Epoch 11/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9687 - loss: 0.1026 - val_accuracy: 0.9512 - val_loss: 0.2416
# Epoch 12/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9733 - loss: 0.0965 - val_accuracy: 0.9512 - val_loss: 0.1232
# Epoch 13/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9759 - loss: 0.0583 - val_accuracy: 0.9512 - val_loss: 0.1174
# Epoch 14/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9912 - loss: 0.0373 - val_accuracy: 0.9634 - val_loss: 0.1468
# Epoch 15/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9891 - loss: 0.0431 - val_accuracy: 0.9512 - val_loss: 0.2511
# Epoch 16/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.9297 - loss: 0.2252 - val_accuracy: 0.9756 - val_loss: 0.0763
# Epoch 17/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.9717 - loss: 0.0707 - val_accuracy: 0.9634 - val_loss: 0.1942
# Epoch 18/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9890 - loss: 0.0321 - val_accuracy: 0.9878 - val_loss: 0.0653
# Epoch 19/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.9659 - loss: 0.0717 - val_accuracy: 0.9878 - val_loss: 0.0423
# Epoch 20/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - accuracy: 0.9705 - loss: 0.0664 - val_accuracy: 0.8659 - val_loss: 0.5149
# Epoch 21/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9520 - loss: 0.1244 - val_accuracy: 0.9390 - val_loss: 0.2443
# Epoch 22/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9393 - loss: 0.1372 - val_accuracy: 0.9390 - val_loss: 0.2431
# Epoch 23/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.9872 - loss: 0.0326 - val_accuracy: 0.9756 - val_loss: 0.1308
# Epoch 24/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.9919 - loss: 0.0248 - val_accuracy: 0.9512 - val_loss: 0.1895
# Epoch 25/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.9975 - loss: 0.0091 - val_accuracy: 0.9634 - val_loss: 0.1186
# Epoch 26/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9512 - val_loss: 0.1629
# Epoch 27/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9981 - loss: 0.0079 - val_accuracy: 0.9512 - val_loss: 0.2019
# Epoch 28/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9876 - loss: 0.0333 - val_accuracy: 0.9634 - val_loss: 0.1967
# Epoch 29/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9879 - loss: 0.0479 - val_accuracy: 0.9634 - val_loss: 0.1543
# Epoch 30/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9969 - loss: 0.0101 - val_accuracy: 0.9756 - val_loss: 0.0971
# Epoch 31/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9512 - val_loss: 0.1612
# Epoch 32/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9634 - val_loss: 0.1386
# Epoch 33/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9756 - val_loss: 0.1003
# Epoch 34/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9634 - val_loss: 0.1407
# Epoch 35/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9634 - val_loss: 0.1931
# Epoch 36/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.9969 - loss: 0.0121 - val_accuracy: 0.9634 - val_loss: 0.2043
# Epoch 37/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9756 - val_loss: 0.0806
# Epoch 38/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9634 - val_loss: 0.1542
# Epoch 39/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9756 - val_loss: 0.1352
# Epoch 40/40
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 1.0000 - loss: 8.6933e-04 - val_accuracy: 0.9756 - val_loss: 0.1180

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.9692 - loss: 0.1974
# [0.13399352133274078, 0.9726027250289917]

# %%
import numpy

plt.figure(figsize=(20,20))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %%
loss, accuracy = model.evaluate(test_ds)

print(f"Test accuracy: {accuracy}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9781 - loss: 0.1142
# Test accuracy: 0.9726027250289917

# %%
model.save('fruitmodel.keras')

# %% [markdown]
# Save the model

# %%
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()

# with open("model.tflite", 'wb') as f:
#   f.write(tflite_model)
